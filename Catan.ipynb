# %%
p1_mia = [8, 8, 10, 6, 7, 7, 4, 8, 9, 7, 7, 8, 7, 6, 9, 8, 5, 10]
p1_tihomir = [3, 9, 3, 7, 5, 12, 11, 4, 3, 7, 11, 9, 8, 7, 8, 7, 7, 9, 5]
p1_wheat = [3, 4, 6]
p1_wool = [3, 6, 9, 10]
p1_wood = [4, 6, 8, 11]
p1_clay = [2, 5, 10]
p1_stone = [5, 8, 12]

p2_mia = [8, 11, 4, 11, 8, 8, 9, 9, 6, 8, 9, 6, 5, 8, 9, 2, 7, 4, 8, 6, 4, 5, 5, 5, 11, 8, 3, 5, 10, 6, 6, 6]
p2_tihomir = [9, 7, 7, 5, 8, 5, 9, 8, 6, 7, 6, 6, 7, 7, 7, 9, 6, 4, 5, 11, 7, 6, 6, 11, 5, 6, 6, 9, 4, 8, 11]
p2_wheat = [6, 8, 9, 10]
p2_wool = [3, 4, 8, 11]
p2_wood = [2, 5, 5, 9]
p2_clay = [10, 11, 12]
p2_stone = [3, 4, 6]

p3_mia = [8, 8, 7, 11, 5, 4, 12, 11, 7, 5, 5, 6, 6, 11, 6, 8, 7, 6, 10, 5, 4]
p3_tihomir = [6, 4, 4, 3, 6, 8, 5, 7, 8, 12, 8, 11, 4, 7, 6, 8, 7, 7, 9, 11, 3, 6]
p3_wheat = [3, 3, 5, 11]
p3_wool = [4, 8, 8, 9]
p3_wood = [2, 6, 9, 11]
p3_clay = [4, 10, 12]
p3_stone = [5, 6, 10]

p4_mia = [6, 3, 5, 5, 5, 6, 10, 8, 12, 4, 6, 5, 8, 10, 6, 6,4, 5, 7]
p4_tihomir = [6, 7, 8, 5, 4, 9, 9, 9, 4, 6, 11, 9, 8, 5, 4, 6, 9, 7, 5]
p4_wheat = [5, 8, 9, 10]
p4_wool = [4, 4, 6, 11]
p4_clay = [3, 4, 8]
p4_stone = [2, 6, 12]

p5_mia = [6, 9, 8, 3, 10, 20, 23, 6, 5, 8, 3, 4, 5, 9, 6, 11, 11, 11, 5, 11, 9, 4]
p5_tihomir = [7, 4, 5, 5, 9, 8, 11, 11, 6, 9, 8, 6, 7, 12, 6, 3, 9, 8, 5, 7, 8, 6, 5]
p5_wheat = [5, 6, 9, 10]
p5_wool = [2, 8, 8, 11]
p5_wood = [6, 9, 10, 11]
p5_clay = [2, 9, 11]
p5_stone= [5, 5, 10]

p6_mia = [10, 9, 3, 8, 6, 5, 7, 5, 7, 9, 6, 4, 11, 8, 10, 10, 7, 6, 5, 6, 8, 9, 9, 7, 4, 9, 10]
p6_tihomir = [8, 11, 7, 3, 8, 4, 3, 6, 4, 7, 7, 7, 7, 2, 7, 5, 4, 7, 9, 4, 9, 8, 4, 10, 9, 7, 4]
p6_wheat = [3, 3, 8, 8]
p6_wool = [4, 4, 6, 12]
p6_wood = [6, 9, 10, 11]
p6_clay = [2, 9, 11]
p6_stone = [5, 5, 10]

p7_mia = [6, 8, 6, 8, 7, 8, 8, 9, 9, 6, 9, 5, 6, 5, 11, 8, 2, 7, 5, 7]
p7_felipe = [7, 8, 8, 4, 9, 4, 7, 7, 4, 6, 4, 7, 7, 4, 4, 7, 6, 8, 8, 8]
p7_tihomir = [5, 12, 10, 7, 5, 8, 7, 6, 4, 8, 9, 11, 9, 9, 4, 5, 9, 9, 7, 4]
p7_wheat = [3, 6, 9, 5]
p7_wool = [3, 6, 8, 12]
p7_wood = [5, 8, 10, 11]
p7_clay = [3, 4, 10]
p7_stone = [4, 9, 11]

p8_felipe = [4, 8, 8, 3, 6, 6, 122, 4, 5, 5, 6, 5, 8, 5, 10, 8, 9, 10]
p8_tihomir =[3, 4, 9, 7, 6, 11, 3, 2, 9, 11, 4, 6, 6, 9, 6, 4, 7, 5]
p8_mia = [10, 11, 5, 5, 8, 5, 3, 4, 7, 8, 10, 8, 8, 6, 7, 10, 6]
#p8_knight = [1.1-6.3 = 0, 6.3 - 9.3 = 6_wheat, 9.3 - 15.3 = 3_stone]
p8_wheat = [4, 6, 11, 11]
p8_wool = [4, 5, 10, 12]
p8_wood = [2, 3, 8, 8]
p8_clay = [6, 9, 10]
p8_stone = [3, 5, 9]

p9_tihomir = [7, 10, 6, 6, 7, 4, 8, 9, 4, 3, 6, 8, 4, 9, 10, 5, 7, 8, 6, 2, 9, 9, 7, 7, 7, 9, 10, 4, 8, 8, 3, 3, 10, 8, 9, 7]
p9_mia = [5, 4, 7, 5, 7, 8, 6, 7, 6, 5, 4, 7, 6, 9, 7, 7, 2, 9, 7, 7, 6, 7, 6, 5, 10, 8, 11, 2, 6, 3, 6, 4, 6, 5, 8]
p9_wheat = [5, 6, 9, 12]
p9_wool = [3, 8, 9, 10]
p9_wood = [2, 3, 6, 11]
p9_clay = [5, 8, 11]
p9_stone = [4, 4, 10]

p10_mia = [6, 6, 3, 10, 8, 11, 7, 5, 11, 9, 9, 7, 4, 8, 4, 5, 6, 6, 6, 6, 4, 4, 8, 9, 7, 8]
p10_tihomir = [ 3, 9, 3, 8, 9, 7, 9, 12, 4, 7, 9, 6, 8, 6, 9, 8, 8, 7, 7, 3, 8, 7, 6, 6, 9]
p10_wheat = [ 2, 9, 8, 12]
p10_wool = [5, 6, 9, 10]
p10_wood = [3, 4, 6, 8]
p10_clay = [5, 10, 11]
p10_stone = [3, 4, 11]

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import random

#Catan game p1

p1 = p1_mia + p1_tihomir

p1_2 = p1.count(2)
p1_3 = p1.count(3) 
p1_4 = p1.count(4)
p1_5 = p1.count(5)
p1_6 = p1.count(6)
p1_7 = p1.count(7)
p1_8 = p1.count(8)
p1_9 = p1.count(9)
p1_10 = p1.count(10)
p1_11 = p1.count(11)
p1_12 = p1.count(12)

numbers = (p1_2, p1_3, p1_4, p1_5, p1_6, p1_7, p1_8, p1_9, p1_10, p1_11, p1_12)

#All the numbers
print("""

Sum of total dice numbers in Catan game p1
        
    """)
for i,a in enumerate(numbers, 2):
      print("number {0} : {1}".format(i,a))

#another aproch to deal with the upper part

def count_elements(p1) -> dict:
    """Tally elements from `seq`."""
    hist = {}
    for i in p1:
        hist[i] = hist.get(i, 0) + 1
    return hist

counted = count_elements(p1)
print("""


Another aproach""")
print(counted)
print("""


""")

#totalWheat

totalWheat = 0
print("Sum of Wheat in Catan game p1 is located on dice tosing: ")
for i, val in enumerate(p1):
     if val == 3:
        totalWheat += 1
        print(i, val)

for i, val in enumerate(p1):
     if val == 4:
        totalWheat += 1
        print(i, val)
        
for i, val in enumerate(p1):
     if val == 6:
        totalWheat += 1
        print(i, val)
print("""


""")

#DataFrame that needs to be fixed

print("Number of resources that each player brought to the Catan game p1 with his dice tosing")
print("""
""")
index = ["Wheat", "Wool", "Wood", "Clay", "Stone"]
frame = pd.DataFrame({'Tihomir': [4, 5, 4, 2, 5],
                      'Mia': [2, 6, 5, 3, 6]},
                    index=index)
print(frame)
print("""


""")

#histograms 
##total

import matplotlib.pyplot as plt
values = [p1]
plt.hist(values, bins = 22)
plt.xlabel("Numbers in game")
plt.ylabel('All numbers')
plt.title('All dice tosing for Catan game p1')
plt.xlim(2,12)
plt.ylim(0, 15)
plt.grid = True 
plt.show()

#mia

values = [p1_mia]
plt.hist(values, bins = 22)
plt.xlabel("Mias numbers")
plt.ylabel('All numbers')
plt.title('Mias dice tosing for Catan game p1')
plt.xlim(2,12)
plt.ylim(0, 10)
plt.grid = True 
plt.show()
#tihomir

values = [p1_tihomir]
plt.hist(values, bins = 22)
plt.xlabel("Tihomirs numbers")
plt.ylabel('All numbers')
plt.title('Tihomirs dice tosing for Catan game p1')
plt.xlim(2,12)
plt.ylim(0, 10)
plt.grid = True 
plt.show()
# Out:
# Sum of total dice numbers in Catan game p1
#
#
# number 2 : 0
# number 3 : 3
# number 4 : 2
# number 5 : 3
# number 6 : 2
# number 7 : 10
# number 8 : 7
# number 9 : 5
# number 10 : 2
# number 11 : 2
# number 12 : 1
#
#
#
# Another aproach
# {8: 7, 10: 2, 6: 2, 7: 10, 4: 2, 9: 5, 5: 3, 3: 3, 12: 1, 11: 2}
#
#
#
#
# Sum of Wheat in Catan game p1 is located on dice tosing:
# 18 3
# 20 3
# 26 3
# 6 4
# 25 4
# 3 6
# 13 6
#
#
#
#
# Number of resources that each player brought to the Catan game p1 with his dice tosing
#
#
#        Tihomir  Mia
# Wheat        4    2
# Wool         5    6
# Wood         4    5
# Clay         2    3
# Stone        5    6
